# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Explorar datos de estaciones limnigráficas

# %% [markdown]
# ![Mapa del Río Magdalena](map.png)

# %%
datos = pd.read_csv("datos_ideam/dosestaciones.csv")

# %%
datos
# Out:
#       CodigoEstacion                   NombreEstacion   Latitud   Longitud  \
# 0           21237020  ARRANCAPLUMAS  - AUT [21237020]  5.202417 -74.727611
# 1           21237020  ARRANCAPLUMAS  - AUT [21237020]  5.202417 -74.727611
# 2           21237020  ARRANCAPLUMAS  - AUT [21237020]  5.202417 -74.727611
# 3           21237020  ARRANCAPLUMAS  - AUT [21237020]  5.202417 -74.727611
# 4           21237020  ARRANCAPLUMAS  - AUT [21237020]  5.202417 -74.727611
# ...              ...                              ...       ...        ...
# 6467        23037010   PUERTO SALGAR - AUT [23037010]  5.469667 -74.662167
# 6468        23037010   PUERTO SALGAR - AUT [23037010]  5.469667 -74.662167
# 6469        23037010   PUERTO SALGAR - AUT [23037010]  5.469667 -74.662167
# 6470        23037010   PUERTO SALGAR - AUT [23037010]  5.469667 -74.662167
# 6471        23037010   PUERTO SALGAR - AUT [23037010]  5.469667 -74.662167
#
#       Altitud     Categoria  \
# 0         222  Limnigráfica
# 1         222  Limnigráfica
# 2         222  Limnigráfica
# 3         222  Limnigráfica
# 4         222  Limnigráfica
# ...       ...           ...
# 6467      186  Limnigráfica
# 6468      186  Limnigráfica
# 6469      186  Limnigráfica
# 6470      186  Limnigráfica
# 6471      186  Limnigráfica
#
#                                                 Entidad  \
# 0     INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 1     INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 2     INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 3     INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 4     INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# ...                                                 ...
# 6467  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 6468  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 6469  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 6470  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 6471  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
#
#                    AreaOperativa  Departamento      Municipio  ...  \
# 0     Area Operativa 10 - Tolima  Cundinamarca        Guaduas  ...
# 1     Area Operativa 10 - Tolima  Cundinamarca        Guaduas  ...
# 2     Area Operativa 10 - Tolima  Cundinamarca        Guaduas  ...
# 3     Area Operativa 10 - Tolima  Cundinamarca        Guaduas  ...
# 4     Area Operativa 10 - Tolima  Cundinamarca        Guaduas  ...
# ...                          ...           ...            ...  ...
# 6467  Area Operativa 10 - Tolima  Cundinamarca  Puerto Salgar  ...
# 6468  Area Operativa 10 - Tolima  Cundinamarca  Puerto Salgar  ...
# 6469  Area Operativa 10 - Tolima  Cundinamarca  Puerto Salgar  ...
# 6470  Area Operativa 10 - Tolima  Cundinamarca  Puerto Salgar  ...
# 6471  Area Operativa 10 - Tolima  Cundinamarca  Puerto Salgar  ...
#
#      FechaSuspension  IdParametro   Etiqueta     DescripcionSerie Frecuencia  \
# 0                NaN       CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
# 1                NaN       CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
# 2                NaN       CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
# 3                NaN       CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
# 4                NaN       CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
# ...              ...          ...        ...                  ...        ...
# 6467             NaN       CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
# 6468             NaN       CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
# 6469             NaN       CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
# 6470             NaN       CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
# 6471             NaN       CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
#
#                  Fecha        Valor  Grado         Calificador NivelAprobacion
# 0     2010-01-01 00:00   480.400000      4  EST. OTROS METODOS             900
# 1     2010-01-02 00:00   425.100000      4  EST. OTROS METODOS             900
# 2     2010-01-03 00:00   425.100000      4  EST. OTROS METODOS             900
# 3     2010-01-04 00:00   489.800000      4  EST. OTROS METODOS             900
# 4     2010-01-05 00:00   590.100000      4  EST. OTROS METODOS             900
# ...                ...          ...    ...                 ...             ...
# 6467  2022-12-27 00:00   844.063375     50                 NaN             900
# 6468  2022-12-28 00:00  1096.882312     50                 NaN             900
# 6469  2022-12-29 00:00  1011.587188     50                 NaN             900
# 6470  2022-12-30 00:00   911.150000     50                 NaN             900
# 6471  2022-12-31 00:00  1570.604062     50                 NaN             900
#
# [6472 rows x 21 columns]

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6472 entries, 0 to 6471
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CodigoEstacion    6472 non-null   int64
#  1   NombreEstacion    6472 non-null   object
#  2   Latitud           6472 non-null   float64
#  3   Longitud          6472 non-null   float64
#  4   Altitud           6472 non-null   int64
#  5   Categoria         6472 non-null   object
#  6   Entidad           6472 non-null   object
#  7   AreaOperativa     6472 non-null   object
#  8   Departamento      6472 non-null   object
#  9   Municipio         6472 non-null   object
#  10  FechaInstalacion  6472 non-null   object
#  11  FechaSuspension   0 non-null      float64
#  12  IdParametro       6472 non-null   object
#  13  Etiqueta          6472 non-null   object
#  14  DescripcionSerie  6472 non-null   object
#  15  Frecuencia        6472 non-null   object
#  16  Fecha             6472 non-null   object
#  17  Valor             6472 non-null   float64
#  18  Grado             6472 non-null   int64
#  19  Calificador       1609 non-null   object
#  20  NivelAprobacion   6472 non-null   int64
# dtypes: float64(4), int64(4), object(13)
# memory usage: 1.0+ MB

# %%
datos["CodigoEstacion"].unique()
# Out:
# array([21237020, 23037010])

# %%
arrancaplumas = datos[datos["CodigoEstacion"] == 21237020]
arrancaplumas
# Out:
#       CodigoEstacion                   NombreEstacion   Latitud   Longitud  \
# 0           21237020  ARRANCAPLUMAS  - AUT [21237020]  5.202417 -74.727611
# 1           21237020  ARRANCAPLUMAS  - AUT [21237020]  5.202417 -74.727611
# 2           21237020  ARRANCAPLUMAS  - AUT [21237020]  5.202417 -74.727611
# 3           21237020  ARRANCAPLUMAS  - AUT [21237020]  5.202417 -74.727611
# 4           21237020  ARRANCAPLUMAS  - AUT [21237020]  5.202417 -74.727611
# ...              ...                              ...       ...        ...
# 1768        21237020  ARRANCAPLUMAS  - AUT [21237020]  5.202417 -74.727611
# 1769        21237020  ARRANCAPLUMAS  - AUT [21237020]  5.202417 -74.727611
# 1770        21237020  ARRANCAPLUMAS  - AUT [21237020]  5.202417 -74.727611
# 1771        21237020  ARRANCAPLUMAS  - AUT [21237020]  5.202417 -74.727611
# 1772        21237020  ARRANCAPLUMAS  - AUT [21237020]  5.202417 -74.727611
#
#       Altitud     Categoria  \
# 0         222  Limnigráfica
# 1         222  Limnigráfica
# 2         222  Limnigráfica
# 3         222  Limnigráfica
# 4         222  Limnigráfica
# ...       ...           ...
# 1768      222  Limnigráfica
# 1769      222  Limnigráfica
# 1770      222  Limnigráfica
# 1771      222  Limnigráfica
# 1772      222  Limnigráfica
#
#                                                 Entidad  \
# 0     INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 1     INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 2     INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 3     INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 4     INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# ...                                                 ...
# 1768  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 1769  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 1770  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 1771  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 1772  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
#
#                    AreaOperativa  Departamento Municipio  ... FechaSuspension  \
# 0     Area Operativa 10 - Tolima  Cundinamarca   Guaduas  ...             NaN
# 1     Area Operativa 10 - Tolima  Cundinamarca   Guaduas  ...             NaN
# 2     Area Operativa 10 - Tolima  Cundinamarca   Guaduas  ...             NaN
# 3     Area Operativa 10 - Tolima  Cundinamarca   Guaduas  ...             NaN
# 4     Area Operativa 10 - Tolima  Cundinamarca   Guaduas  ...             NaN
# ...                          ...           ...       ...  ...             ...
# 1768  Area Operativa 10 - Tolima  Cundinamarca   Guaduas  ...             NaN
# 1769  Area Operativa 10 - Tolima  Cundinamarca   Guaduas  ...             NaN
# 1770  Area Operativa 10 - Tolima  Cundinamarca   Guaduas  ...             NaN
# 1771  Area Operativa 10 - Tolima  Cundinamarca   Guaduas  ...             NaN
# 1772  Area Operativa 10 - Tolima  Cundinamarca   Guaduas  ...             NaN
#
#       IdParametro   Etiqueta     DescripcionSerie Frecuencia  \
# 0          CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
# 1          CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
# 2          CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
# 3          CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
# 4          CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
# ...           ...        ...                  ...        ...
# 1768       CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
# 1769       CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
# 1770       CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
# 1771       CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
# 1772       CAUDAL  Q_MEDIA_D  Caudal medio diario     Diaria
#
#                  Fecha  Valor  Grado         Calificador NivelAprobacion
# 0     2010-01-01 00:00  480.4      4  EST. OTROS METODOS             900
# 1     2010-01-02 00:00  425.1      4  EST. OTROS METODOS             900
# 2     2010-01-03 00:00  425.1      4  EST. OTROS METODOS             900
# 3     2010-01-04 00:00  489.8      4  EST. OTROS METODOS             900
# 4     2010-01-05 00:00  590.1      4  EST. OTROS METODOS             900
# ...                ...    ...    ...                 ...             ...
# 1768  2014-12-27 00:00  708.2     50                 NaN             900
# 1769  2014-12-28 00:00  654.0     50                 NaN             900
# 1770  2014-12-29 00:00  622.6     50                 NaN             900
# 1771  2014-12-30 00:00  575.9     50                 NaN             900
# 1772  2014-12-31 00:00  666.8     50                 NaN             900
#
# [1773 rows x 21 columns]

# %%
arrancaplumas = arrancaplumas[["Fecha", "Valor"]]
arrancaplumas
# Out:
#                  Fecha  Valor
# 0     2010-01-01 00:00  480.4
# 1     2010-01-02 00:00  425.1
# 2     2010-01-03 00:00  425.1
# 3     2010-01-04 00:00  489.8
# 4     2010-01-05 00:00  590.1
# ...                ...    ...
# 1768  2014-12-27 00:00  708.2
# 1769  2014-12-28 00:00  654.0
# 1770  2014-12-29 00:00  622.6
# 1771  2014-12-30 00:00  575.9
# 1772  2014-12-31 00:00  666.8
#
# [1773 rows x 2 columns]

# %%
arrancaplumas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1773 entries, 0 to 1772
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Fecha   1773 non-null   object
#  1   Valor   1773 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 41.6+ KB

# %%
#https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes
arrancaplumas["Fecha"] = pd.to_datetime(arrancaplumas["Fecha"], format=r"%Y-%m-%d %H:%M")
# Out:
# /tmp/ipykernel_829/2360240582.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   arrancaplumas["Fecha"] = pd.to_datetime(arrancaplumas["Fecha"], format=r"%Y-%m-%d %H:%M")

# %%
arrancaplumas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1773 entries, 0 to 1772
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Fecha   1773 non-null   datetime64[ns]
#  1   Valor   1773 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 41.6 KB

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.plot(arrancaplumas["Fecha"], arrancaplumas["Valor"])
ax.set_xlabel("Fecha", fontsize=14)
ax.set_ylabel("Caudal medio diario [m³/d]", fontsize=14)
plt.show()

# %%
puertosalgar = datos[datos["CodigoEstacion"] == 23037010]
puertosalgar = puertosalgar[["Fecha", "Valor"]]
puertosalgar["Fecha"] = pd.to_datetime(puertosalgar["Fecha"], format=r"%Y-%m-%d %H:%M")
puertosalgar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4699 entries, 1773 to 6471
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Fecha   4699 non-null   datetime64[ns]
#  1   Valor   4699 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 110.1 KB

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.plot(puertosalgar["Fecha"], puertosalgar["Valor"])
ax.set_xlabel("Fecha", fontsize=14)
ax.set_ylabel("Caudal medio diario [m³/d]", fontsize=14)
plt.show()

# %% [markdown]
# ## Combinar datos para presentación

# %%
fig, ax = plt.subplots(figsize=(12,5))
ax.plot(puertosalgar["Fecha"], puertosalgar["Valor"], label="Puerto Salgar", lw=1)
ax.plot(arrancaplumas["Fecha"], arrancaplumas["Valor"], label="Arrancaplumas", lw=1)
ax.set_xlabel("Fecha", fontsize=14)
ax.set_ylabel("Caudal medio diario [m³/d]", fontsize=14)
ax.legend()
plt.show()

# %%
combinado = arrancaplumas.merge(puertosalgar, on="Fecha", suffixes=["_Arrancaplumas","_PuertoSalgar"])
combinado
# Out:
#           Fecha  Valor_Arrancaplumas  Valor_PuertoSalgar
# 0    2010-01-01                480.4               557.7
# 1    2010-01-02                425.1               510.9
# 2    2010-01-03                425.1               500.1
# 3    2010-01-04                489.8               633.0
# 4    2010-01-05                590.1               693.7
# ...         ...                  ...                 ...
# 1744 2014-12-27                708.2               788.1
# 1745 2014-12-28                654.0               729.5
# 1746 2014-12-29                622.6               647.5
# 1747 2014-12-30                575.9               602.4
# 1748 2014-12-31                666.8              1105.0
#
# [1749 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(7,7))
ax.set_aspect("equal")
ax.scatter(combinado["Valor_PuertoSalgar"], combinado["Valor_Arrancaplumas"], marker=".", s=10)
ax.set_xlabel("CMD Puerto Salgar [m³/s]", fontsize=14)
ax.set_ylabel("CMD Arrancaplumas [m³/s]", fontsize=14)
ax.set_ylim(0, 7000)
ax.set_xlim(0, 7000)
ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)
plt.show()

# %%
combinado.describe(percentiles=[.20,.50,.90])
# Out:
#        Valor_Arrancaplumas  Valor_PuertoSalgar
# count          1749.000000         1749.000000
# mean           1257.278674         1554.370783
# std             638.741245          878.427034
# min             270.200000          372.300000
# 20%             744.000000          865.860000
# 50%            1098.000000         1342.000000
# 90%            2152.800000         2654.000000
# max            4557.000000         6488.000000

# %%
from scipy.stats import linregress
regresión = linregress(combinado["Valor_PuertoSalgar"], combinado["Valor_Arrancaplumas"])

# %%
regresión
# Out:
# LinregressResult(slope=0.7014422758413212, intercept=166.9772937851924, rvalue=0.9646564437029675, pvalue=0.0, stderr=0.004584281172126638, intercept_stderr=8.184272637450386)

# %%
label_regresión = f"""Regresión Lineal: 
$y = {regresión.slope:.3f} * x + {regresión.intercept:.1f}$
R² = {regresión.rvalue**2:.3f}"""

# %%
fig, ax = plt.subplots(figsize=(7,7))
ax.set_aspect("equal")
ax.scatter(combinado["Valor_PuertoSalgar"], combinado["Valor_Arrancaplumas"], marker=".", s=10)
ax.axline((0,regresión.intercept), slope=regresión.slope, label=label_regresión, ls="dashed", c="k")
ax.set_xlabel("CMD Puerto Salgar [m³/s]", fontsize=14)
ax.set_ylabel("CMD Arrancaplumas [m³/s]", fontsize=14)
ax.set_ylim(0, 7000)
ax.set_xlim(0, 7000)
ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)
ax.legend(fontsize=12)
plt.show()
